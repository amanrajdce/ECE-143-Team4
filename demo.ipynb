# %%
import sys
import warnings
warnings.filterwarnings("ignore")
sys.path.append("../")
from analysis_review_and_ceo import *

# %%
review_table = './Scraper/ReviewScraper/merged_reviews_table.csv'
ceo_table = './Scraper/ReviewScraper/ceo_ratings.csv'

# %%
plot_city_most_jobs(review_table)

# %%
plot_state_most_jobs(review_table)

# %%
plot_approve_of_ceo(ceo_table)

# %%
plot_career_comp_rating(review_table)

# %%
plot_pos_neg_reviews(review_table)

# %% [markdown]
# ## Salary analysis

# %%
from salary_analysis import *

# %%
salary_data = pd.read_csv('./Scraper/SalaryScraper/fulltime_merged_salaries_company_table.csv')
salary_data_int = pd.read_csv('./Scraper/SalaryScraper/intern_merged_salaries_company_table.csv')

# %%
plot_average_fulltime_by_category(salary_data)

# %%
plot_distribution_category(salary_data)

# %%
plot_average_intern_by_category(salary_data_int)

# %%
plot_average_fulltime_salary_company(salary_data)

# %%
plot_average_intern_salary_company(salary_data_int)

# %%
plot_num_of_jobs_category(salary_data)
